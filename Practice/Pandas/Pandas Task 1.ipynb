# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ###`Q-1:` Write a program to create an empty series.

# %%
lst = []

empty_series = pd.Series(lst)

type(empty_series)
# Out:
# pandas.Series

# %% [markdown]
# ###`Q-2:` Write a Pandas program to add, subtract, multiple and divide two Pandas Series.

# %%
def arith(*series): 
    add = series[0] + series[1]
    sub = series[0] - series[1]
    mul = series[0] * series[1]
    div = series[0] / series[1]

    print(f'---- Addition ---- \n{add}\n')
    print(f'---- Subtraction ---- \n{sub}\n')
    print(f'---- Multiplication ---- \n{mul}\n')
    print(f'---- Divistion ---- \n{div}\n')

series_1 = pd.Series([1, 2, 3, 4])
series_2 = pd.Series([1, 2, 3, 4])


arith(series_1, series_2)
# Out:
# ---- Addition ----
# 0    2
# 1    4
# 2    6
# 3    8
# dtype: int64
#
# ---- Subtraction ----
# 0    0
# 1    0
# 2    0
# 3    0
# dtype: int64
#
# ---- Multiplication ----
# 0     1
# 1     4
# 2     9
# 3    16
# dtype: int64
#
# ---- Divistion ----
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# dtype: float64

# %% [markdown]
# ###`Q-3` Write a Pandas program to compare the elements of the two Pandas Series.
# Sample Series: [2, 4, 6, 8, 10], [1, 3, 5, 7, 10]

# %%
s1 = pd.Series([2, 4, 6, 8, 10])
s2 = pd.Series([1, 3, 5, 7, 10])

s1 > s2
s1 < s2
s1 == s2
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
s1.gt(s2)
s1.lt(s2)
s1.eq(s2)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %% [markdown]
# ###`Q-5.`Write a function to change the data type of given a column or a Series. Function takes series and data type as input, returns the converted series.
# ```
# series = pd.Series([1,2,'Python', 2.0, True, 100])
# change to float type data
# ```
# Note: Read about pd.to_numeric()

# %%
sereies = pd.Series([1, 2, 'Python', 2.0, True, 100])

pd.to_numeric(sereies, errors='coerce')
# Out:
# 0      1.0
# 1      2.0
# 2      NaN
# 3      2.0
# 4      1.0
# 5    100.0
# dtype: float64

# %% [markdown]
# Download data - https://drive.google.com/file/d/1LRhXwbEodeWXtzPhJCX0X9Lf_BECzvqb/view?usp=share_link
# All Batsman runs series in IPL 2008 to 2022.
#
# Below questions are based on this data.

# %%
batsman = pd.read_csv('Practice/Pandas/datasets/batsman_runs_series.csv', index_col='batter').squeeze()

batsman
# Out:
# batter
# A Ashish Reddy     280
# A Badoni           161
# A Chandila           4
# A Chopra            53
# A Choudhary         25
#                   ...
# Yash Dayal           0
# Yashpal Singh       47
# Younis Khan          3
# Yuvraj Singh      2754
# Z Khan             117
# Name: batsman_run, Length: 605, dtype: int64

# %% [markdown]
# ###`Q-6` Find top 10 most run getter from the series.

# %%
top_10_run_getter = batsman.sort_values(ascending=False).head(10)

print(f'Top 10 run getter: {top_10_run_getter}')
# Out:
# Top 10 run getter: batter
# V Kohli           6634
# S Dhawan          6244
# DA Warner         5883
# RG Sharma         5881
# SK Raina          5536
# AB de Villiers    5181
# CH Gayle          4997
# MS Dhoni          4978
# RV Uthappa        4954
# KD Karthik        4377
# Name: batsman_run, dtype: int64

# %%
# Directly find the 10 largest values
batsman.nlargest(10)
# Out:
# batter
# V Kohli           6634
# S Dhawan          6244
# DA Warner         5883
# RG Sharma         5881
# SK Raina          5536
# AB de Villiers    5181
# CH Gayle          4997
# MS Dhoni          4978
# RV Uthappa        4954
# KD Karthik        4377
# Name: batsman_run, dtype: int64

# %% [markdown]
# ###`Q-7` No of players having runs above 3000

# %%
batsman[batsman > 3000].size
# Out:
# 20

# %%
(batsman > 3000).sum()
# Out:
# np.int64(20)

# %% [markdown]
# ###`Q-8` No of players having runs above mean value?

# %%
(batsman > batsman.mean()).sum()
# Out:
# np.int64(128)

# %% [markdown]
# Download data - https://drive.google.com/file/d/1QZuZ5bypUInfVvarHACLAi8tXXHvb8xd/view?usp=share_link
#
# file name - items.csv

# %%
items = pd.read_csv('Practice/Pandas/datasets/items.csv', index_col='item_name').squeeze()

items
# Out:
# item_name
# Chips and Fresh Tomato Salsa              $2.39
# Izze                                      $3.39
# Nantucket Nectar                          $3.39
# Chips and Tomatillo-Green Chili Salsa     $2.39
# Chicken Bowl                             $16.98
#                                           ...
# Steak Burrito                            $11.75
# Steak Burrito                            $11.75
# Chicken Salad Bowl                       $11.25
# Chicken Salad Bowl                        $8.75
# Chicken Salad Bowl                        $8.75
# Name: item_price, Length: 4622, dtype: str

# %% [markdown]
# ###`Q-9`
#     i. Read `items.csv` making `item_name` as index.
#     ii. Show no of nan values
#     ii. Item price is given in $, so convert it to rupees without currency symbol.
#     iii. Make data type of newly made series as float.
#     iv. Fill nan with mean of the series
#
#
# How csv file looks
#
# ```
# item_name	item_price
# Chips and Fresh Tomato Salsa	$2.39
# Izze	$3.39
# Nantucket Nectar	$3.39
# Chips and Tomatillo-Green Chili Salsa	$2.39
# Chicken Bowl	$16.98
#
# ```

# %%
# Fetching the nan values
items[items.isna()]
# Out:
# item_name
# Side of Chips                         NaN
# Steak Soft Tacos                      NaN
# Chips                                 NaN
# Chicken Burrito                       NaN
# Veggie Bowl                           NaN
# Steak Salad Bowl                      NaN
# Chicken Salad Bowl                    NaN
# Barbacoa Burrito                      NaN
# Chicken Soft Tacos                    NaN
# Chicken Bowl                          NaN
# Steak Burrito                         NaN
# Chips and Guacamole                   NaN
# Chips and Roasted Chili Corn Salsa    NaN
# Chips and Fresh Tomato Salsa          NaN
# Steak Bowl                            NaN
# Steak Burrito                         NaN
# Chicken Bowl                          NaN
# Canned Soft Drink                     NaN
# Chicken Soft Tacos                    NaN
# Steak Burrito                         NaN
# Steak Burrito                         NaN
# Steak Burrito                         NaN
# ...

# %%
# Covert currency in rupees from dollor and values to float
items = pd.to_numeric(items.str.replace('$', '', regex=False))

# %%
# Filling NaN values with mean
items[items.isna()] = items.mean()

# %%
items.fillna(items.mean())
# Out:
# item_name
# Chips and Fresh Tomato Salsa              2.39
# Izze                                      3.39
# Nantucket Nectar                          3.39
# Chips and Tomatillo-Green Chili Salsa     2.39
# Chicken Bowl                             16.98
#                                          ...
# Steak Burrito                            11.75
# Steak Burrito                            11.75
# Chicken Salad Bowl                       11.25
# Chicken Salad Bowl                        8.75
# Chicken Salad Bowl                        8.75
# Name: item_price, Length: 4622, dtype: float64

# %% [markdown]
# ###`Q-10`:
#     i. Find mean price
#     ii. Find 30th and 6th percentile value
#     iii. Plot Histogram on price with bin size 50
#     iv. No of items price lies between [1000 to 2000]

# %%
print(f'Mean price: {items.mean()}')
# Out:
# Mean price: 7.4630314960629915

# %%
items.quantile(0.30)
items.quantile(0.06)
# Out:
# np.float64(1.25)

# %%
items.plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
count = items.between(1000, 2000).sum()
print('Number of items: ', count)
# Out:
# Number of items:  0
